# %% [markdown]
# <a href="https://colab.research.google.com/github/diljithg05/AI-Basics/blob/main/moodalyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sentiment Analysis on Tweets using TextBlob
# -------------------------------------------
# Run this cell to install TextBlob

# %%
# !pip install textblob

# %%
# Import necessary libraries

# %%
from textblob import TextBlob

# %%
import pandas as pd

# %%
# Sample tweet data (you can replace this with real tweet text)

# %%
data = {
    'Tweet': [
        "I love the new phone I bought!",
        "I'm feeling so down today.",
        "It's just an average day.",
        "This product is amazing 😍",
        "Terrible service. Never buying again!",
        "The weather is okay, not bad at all.",
        "Best movie I've seen this year!",
        "Worst experience of my life.",
        "Had a good day at work today.",
        "Nothing special, just a regular morning."
    ]
}

# %%
# Create DataFrame

# %%
df = pd.DataFrame(data)

# %%
# Function to analyze sentiment
def analyze_sentiment(tweet):
    blob = TextBlob(tweet)
    polarity = blob.sentiment.polarity
    if polarity > 0:
        return 'Positive'
    elif polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

# %%
# Apply the function
df['Sentiment'] = df['Tweet'].apply(analyze_sentiment)

# %%
# Show results
df
# Out:
#                                       Tweet Sentiment
# 0            I love the new phone I bought!  Positive
# 1                I'm feeling so down today.  Negative
# 2                 It's just an average day.  Negative
# 3                 This product is amazing 😍  Positive
# 4     Terrible service. Never buying again!  Negative
# 5      The weather is okay, not bad at all.  Positive
# 6           Best movie I've seen this year!  Positive
# 7              Worst experience of my life.  Negative
# 8             Had a good day at work today.  Positive
# 9  Nothing special, just a regular morning.  Positive
